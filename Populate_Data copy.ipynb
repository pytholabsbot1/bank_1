# %% [markdown]
# # Custom initailize data :
#
# Groups
# bank choices
# branch choice
# city_choice
# Country_ choices
# Deposit choices
# District_ choices
# Finance choices
# Id_ type_ choices
# Relation_ choices
# State_ choices
# Schemes

# %% [markdown]
# # SETUP

# %%
from django.conf import settings
import django , time

from sidhi_society.settings import DATABASES, INSTALLED_APPS
settings.configure(DATABASES=DATABASES, INSTALLED_APPS=INSTALLED_APPS)
django.setup()

# %%
from employee import models
import datetime
from dateutil.relativedelta import relativedelta
from dateutil import parser
from django.contrib.auth.models import User
from importlib import reload
import numpy as np
from threading import Thread
from ipywidgets import IntProgress
from IPython.display import display
from IPython.display import clear_output
reload(models)

def rand_string(t,l):
    if(t=='int'):
        return ''.join([random.choice(string.digits) for i in range(l)]) 
    else:
        return ''.join([random.choice(string.ascii_letters) for i in range(l)])

def chunks(l, n):
    n = max(1, n)
    return [l[i:i+n] for i in range(0, len(l), n)]
# Out:
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.finance_table' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.approved_finance_table' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.deposits_table' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.collection_finance' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.collection_deposit' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.withdrawl_entry' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.voucher' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.cheque_details' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.cash_notes' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.voucherparticulars' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.voucherhead' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.payment_voucher' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.contra_voucher' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.journal_voucher' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.cash_collection' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.emp_payments' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)
# /Users/vaqasahmed/opt/miniconda3/lib/python3.7/site-packages/django/db/models/base.py:320: RuntimeWarning: Model 'employee.uploaddocs' was already registered. Reloading models is not advised as it can lead to inconsistencies, most notably with related models.
#   new_class._meta.apps.register_model(new_class._meta.app_label, new_class)

# %% [markdown]
# # INITAIL DATA

# %%
from faker import Faker
fake = Faker()

fake.phone_number()
# Out:
# '001-407-006-1216x5304'

# %%
### .>>> Create Employee Group First

def create_choices():
    
    User.objects.all().delete() 
    User.objects.create_user(username="admin" ,password="vaqasahmed",is_staff=1,is_superuser=1 , first_name="sidhi" , last_name= "society")
    

    ##remove all emp
    models.client.objects.all().delete()
    models.employee_interview.objects.all().delete()
    
    
    #delete all shit
    models.Bank_Choice.objects.all().delete()
    models.City_Choice.objects.all().delete()
    models.Country_Choice.objects.all().delete()
    models.District_Choice.objects.all().delete()
    models.Id_Type_Choice.objects.all().delete()
    models.State_Choice.objects.all().delete()
    
    
    #populate
    models.Bank_Choice(bank_choice="icici").save()
    models.City_Choice(city_choice = "DAUSA").save()
    models.Country_Choice(country_choice="INDIA").save()
    models.District_Choice(district_choice ="LALSOT").save()
    models.Id_Type_Choice(id_type_choice ="Adhaar").save()
    models.State_Choice(state_choice = "RAJASTHAN").save()
    
    
    #delete the populate
    models.Balance.objects.all().delete()
    models.Balance(cash=0 , bank=0).save()
    
    models.DepositChoice.objects.all().delete()
    models.DepositChoice(name="FD" , emi_type="one time").save()
    models.DepositChoice(name="RD" , emi_type="months").save()
    models.DepositChoice(name="CA" , emi_type="days").save()
    
    models.FinanceChoice.objects.all().delete()
    models.FinanceChoice(name="Personal" ).save()
    models.FinanceChoice(name="Home Loan" ).save()
    
    models.Scheme.objects.all().delete()
    models.Scheme(name = "CA fast" , interest_rate=4).save()
    models.Scheme(name = "FD fast" , interest_rate=8 , duration=np.random.randint(1,5)).save()
    models.Scheme(name = "RD fast" , interest_rate=6 , duration=np.random.randint(1,5)).save()
    
Thread(target=create_choices ,).start()

# %%
c_max = 10
c_curr = 0

def create_emp():
    global c_curr
    input("Have you created Group for employee? ")
    
    #delete the shit
    models.employee_interview.objects.all().delete()
    
    #populate 100 agents
    for i in range(10):
        profile_data = {
            'first_name' : fake.first_name() ,
            'last_name' : fake.last_name() ,
            'father_name' : fake.name() ,
            'date_of_birth' : fake.date_of_birth(tzinfo=None, minimum_age=18, maximum_age=50) , 
            'mobile_number_1' : '8094011162',
            'photograph' : f'person/{np.random.randint(1,115)}.png'
        }

        e = models.employee_interview(**profile_data)
        nm = e.nomination_number
        e.save()

        e = models.employee_interview.objects.get(nomination_number=nm)
        models.employee_joining( employee = e,salary=20000, total=20000).save()
        
        if(c_curr%10 ==0):
            clear_output()
        
        c_curr+=1
        
        p = int( c_curr / c_max *100 )
        print('i'*p , p,"%")
    

Thread(target=create_emp ,).start()
# Out:
# iiiiiiiiii 10 %
# Juan
# iiiiiiiiiiiiiiiiiiii 20 %
# Jason
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiii 30 %
# Tonya
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 40 %
# Sheila
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 50 %
# Sharon
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 60 %
# Jason
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 70 %
# John
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 80 %
# Amy
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 90 %
# Karl
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 100 %

# %%
e_max = 20
e_curr = 0

def create_client():
    global e_curr
    ##delete thean fuck clients
    models.client.objects.all().delete()
    
    for i in range(20):
        
        profile_data = {
            'first_name' : fake.first_name() ,
            'last_name' : fake.last_name() ,
            'father_name' : fake.name() ,
            'date_of_birth' : fake.date_of_birth(tzinfo=None, minimum_age=18, maximum_age=50) , 
            'mobile_number_1' : '8094011162',
            'agent_name' : models.employee_interview.objects.all()[np.random.randint(0,10)],
            'sharing_amount' : 1000,
            'nomination_fees' : 2000,
            'photograph' : f'person/{np.random.randint(1,115)}.png'
        }
        
        try:
            c = models.client(**profile_data)
            c.save()
        except:
            print('eroorr ---')
            
        if(e_curr%20 ==0):
            clear_output()
        
        e_curr+=1
        
        p = int( e_curr / e_max *100 )
        print('i'*p , p,"%")

Thread(target=create_client ,).start()
# Out:
# iiiii 5 %
# iiiiiiiiii 10 %
# iiiiiiiiiiiiiii 15 %
# iiiiiiiiiiiiiiiiiiii 20 %
# iiiiiiiiiiiiiiiiiiiiiiiii 25 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiii 30 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 35 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 40 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 45 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 50 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 55 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 60 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 65 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 70 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 75 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 80 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 85 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 90 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 95 %
# iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii 100 %

# %%
def create_fc():
    
    #delete the shit and then populate
    models.finance_table.objects.all().delete()
    
    for i in range(10):
        cl = models.client.objects.all()[np.random.randint(0,10)]
        amt = np.random.randint(100000,1000001)

        start_date  = parser.parse("2015-04-01") 
        d = np.random.randint(1,8)
        t_delta = relativedelta(months=+d)
        
        ###quaterly duration should be larger than 3 months
        emi_tp = np.random.choice(['Monthly','Quaterly','OneTime'])
        d_type = np.random.choice(['months','years']) 
        
        if(emi_tp=="Quaterly" and d_type=="months"):
            duration = np.random.randint(4, 20)
        else:
            duration = np.random.randint(2, 10)
       
        profile_data = {
            'person' :  cl ,
            'demanded_amount' :  amt,
            'loan_duration' :  duration,
            'duration_type' : d_type, 
            'emi_type' : emi_tp,
            'loan_type' : models.FinanceChoice.objects.all()[np.random.randint(0,2)],
            'agent_name' : cl.agent_name,
            'expected_amount' : amt-30000 ,
            'applied_date' : start_date + t_delta ,
            'expected_date' : start_date + t_delta + relativedelta(months=+1),
        }

        c = models.finance_table(**profile_data)
        ln_num = c.loan_account_number
        c.save()

        ## APProval part
        fc = models.finance_table.objects.get(loan_account_number=ln_num)
        app_fc = {
            'finance' : fc ,
            'person' : fc.person,
            'client_bank_account_number' : fake.iban()[:-5] ,
            'loan_start_date' : fc.expected_date ,
            'loan_duration' : fc.loan_duration,
            'duration_type' : fc.duration_type ,
            'roi' : np.random.randint(5, 14) ,
            'emi_type' : fc.emi_type ,
            'discount' : np.random.randint(100, 500) ,
            'counter_number' : np.random.randint(1, 100),
            'sanctioned_amount' : fc.expected_amount
        }


        models.approved_finance_table(**app_fc).save()
 
# reload(models)

Thread(target=create_fc ,).start()
# Out:
# Quaterly 2020-04-06 2021-07-06 456
# ---->  5
# OneTime 2020-04-06 2020-11-06 214
# ---->  1
# OneTime 2020-04-06 2020-11-06 214
# ---->  1
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# OneTime 2020-04-06 2025-04-06 1826
# ---->  1
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# Quaterly 2020-04-06 2021-03-06 334
# ---->  3
# OneTime 2020-04-06 2025-04-06 1826
# ---->  1
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48

# %%
def create_dp():
    
    #delete the shit and then populate
    models.deposits_table.objects.all().delete()
    
    for i in range(10):
        cl = models.client.objects.all()[np.random.randint(0,20)]
        amt = np.random.randint(100000,1000001) - 3000

        start_date  = parser.parse("2015-04-01") 
        d = np.random.randint(1,8)
        t_delta = relativedelta(months=+d)
        start_date = start_date + t_delta
        
        cat = np.random.choice(models.DepositChoice.objects.all())
        scheme = [i for i in models.Scheme.objects.all() if(cat.name in i.name)][0]
        
        profile_data = {
            'person' :  cl ,
            'account_opening_date' :  start_date ,
            'account_opening_amount' : amt,     
            'scheme' : scheme ,
            'agent_name' : models.employee_interview.objects.all()[np.random.randint(0,10)],
            'client_bank_account_number' : fake.iban(),
            'counter_number' : np.random.randint(1, 100),
            'category' : cat
        }
        
        if('CA' not in scheme.name):
            r_del = eval(f'relativedelta({scheme.duration_type}=+{scheme.duration})')
            m_date =  start_date + r_del
            profile_data['maturity_date'] = m_date
            
            diff_amt = scheme.per_day_roi * (m_date - start_date).days * amt
            profile_data['maturity_amount'] = amt + diff_amt
            print(amt ,(m_date - start_date).days , scheme.per_day_roi ,diff_amt)

        c = models.deposits_table(**profile_data)
        c.save()
        
        print(cat.name)
  
#reload(models)
Thread(target=create_dp ,).start()
# Out:
# CA
# 214911 366 0.000219178082191781 17239.98378082193
# FD
# 518389 366 0.000219178082191781 41584.73950684934
# FD
# CA
# 126714 366 0.000164383561643836 7623.669698630155
# RD
# 577403 366 0.000219178082191781 46318.79408219182
# FD
# 486598 366 0.000164383561643836 29275.868712328836
# RD
# 515032 366 0.000219178082191781 41315.44372602743
# FD
# CA
# CA

# %% [markdown]
# # DEPOSIT DATA

# %%
d_max = 100
d_curr = 0

def dp_coll(arg):
    global d_curr
    print('new  -------------------------- ')
    args = chunks(models.deposits_table.objects.all() , 1)[arg]
    
    for deposit in args:
        
#         print(deposit.agent_name.nomination_number)
#         break
        
        start_date = deposit.account_opening_date
        
        if(deposit.category.name=='CA'):
            d = np.random.randint(4,30)
            t_delta = relativedelta(days=+d)
            
        elif(deposit.category.name=='RD'):
            t_delta = relativedelta(months=+1)
            
        else:
            continue
            
        
        end_date = start_date + t_delta
        
        for i in range(np.random.randint(20,50)):

            tot_interest = deposit.interest_collected 
            balance = deposit.balance

            payment_received = np.random.choice(np.arange(500 , 2000 ,100))

            ##Computing --------
            latest_col = deposit.collection_deposit_set.all().order_by('-id')     
            if(latest_col):
                days = abs((end_date - latest_col[0].payment_received_date).days)
            else:
                days = abs((end_date - deposit.account_opening_date).days)

              #calculate interest till date from last collection
            interest_delta = (balance * deposit.scheme.per_day_roi) * days

            #add with last interest 
            tot_interest +=  interest_delta


            ##Updating on database ----------
            k_ = {"deposit" : deposit,
                 "payment_received_date" : end_date ,
                  "payment_received" : payment_received,
                  "previous_balance" : balance,
                  "agent_name" : deposit.agent_name,
                  "latest_intrest" : tot_interest,
                  "person" : deposit.person
                 }


            models.collection_deposit(**k_).save()
            end_date += t_delta

            #update in employee records
            deposit.agent_name.deposit_coll += payment_received
            deposit.agent_name.save()

            deposit.interest_collected += interest_delta
            deposit.balance += payment_received
            deposit.save()

            #update for admin insights in category
            c = models.DepositChoice.objects.get(id=deposit.category.id)
            c.amount += payment_received
            c.save()
            
                
        if(d_curr%20 ==0):
            clear_output()

        d_curr+=1

        p = int( d_curr / d_max *100 )
        print('i'*p , p,"%")

    #         print(payment_received , ' ----- -')

    
for arg in range(10):
# reload(models)
    Thread(target=dp_coll ,args=(arg , )).start()
# Out:
# i 1 %
# ii 2 %
# iii 3 %
# iiii 4 %
# iiiii 5 %
# iiiiii 6 %

# %% [markdown]
# # FINANCE DATA

# %%
def fc_coll(arg):
     
    print('new  -------------------------- ')
    finances = chunks(models.approved_finance_table.objects.all() , 1)[arg]
    
    for finance in finances:
        
        try:
            d_ = finance.emi_delta.split()
            print(d_)
            delta = eval(f"relativedelta({d_[1]}=+{d_[0]})")


            emi_date = finance.loan_start_date + delta

            emp = finance.finance.agent_name

            for i in range(finance.no_of_emi):

                k_ = {'finance': finance,
                     "loan_emi_received_date" : emi_date,
                     "agent_name": emp,
                      "person" : finance.finance.person,
                      "loan_emi_received" : finance.emi_amount

                     }


                models.collection_finance(**k_).save()


                 #update in employee records
                emp.finance_coll += finance.emi_amount
                emp.save()

                finance.recieved += finance.emi_amount
                finance.save()

                #update for admin insights in category
                c = models.FinanceChoice.objects.get(id=finance.finance.loan_type.id)
                c.amount += finance.emi_amount
                c.save()
                
        except:
            print('error')
            
        print(finance)

for arg in range(10):
    Thread(target=fc_coll ,args=(arg , )).start()
# Out:
# new  --------------------------
# new  -------------------------- new  --------------------------
# new  --------------------------
#
# new  --------------------------
# new  --------------------------
# new  --------------------------
# new  --------------------------
# new  --------------------------
# new  --------------------------
# ['3', 'months']
# ['None']
# error
# ['None']
# error
# ['3', 'months']John Nomination Number SCC604458['1', 'months']
#
#
# 0.0William Nomination Number SCC094589
#  831620.5
# ['1', 'months']['None']
# ['3', 'months']
# ['None']error
#
# error
#
# 0.0 968816.9
# 0.0Taylor Nomination Number SCC860725
#  588523.02Bethany Nomination Number SCC883620['1', 'months']0.0Quaterly
#
#  2020-04-06 2021-07-06 456
# ---->  5
#
# 1028242.39
# Monthly0.0 2020-04-06 2022-04-06 730
# ---->  24
# 0.0QuaterlyMonthly 909912.86
#   2020-04-06 2026-04-06  626233.84
# 2020-04-062191
# ---->  24
#  Monthly2024-04-06 1461
# ---->  48
#  166324.140367.3708333333Quaterly2020-04-06  968816.9
# 831620.5
#  2020-04-06 2021-03-06 334
# ---->  3
#  Quaterly2027-04-06 2020-04-06 2021-07-06 456
# ---->  5
#  2556
# ---->  84
# 24521.7925 588523.02
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# 208744.61333333321421.7164583333 626233.84
# Quaterly 1028242.39
#  2020-04-06 2026-04-06 2191
# ---->  24
# 332648.2 831620.5
# 10832.295952381Quaterly 909912.86
#  2020-04-06 2021-03-06 334
# ---->  3
# MonthlyQuaterly80734.74166666664   968816.9
# 2020-04-062020-04-06 2021-07-06 456 2024-04-06 1461
# ---->  48
#
# 49043.585---->  5
#  588523.02
# MonthlyMonthly 2020-04-06 2027-04-06 2556
# ---->  84
#  2020-04-06 2022-04-06 730
# ---->  24
# 417489.2266666663342843.43291666663 626233.84
#  1028242.39
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# MonthlyQuaterly498972.30000000005 2020-04-06 2024-04-06 1461
# ---->  48
#  2020-04-06 2021-03-06 334
# ---->  3
#  21664.591904761954 909912.86
# 831620.5
# 121102.11249999997 968816.9
# 73565.3775Bethany Nomination Number SCC883620 588523.02
#
# Monthly64265.149374999964Monthly Quaterly 2020-04-06 2027-04-06 2556
# ---->  84
#  1028242.39
# Quaterly2020-04-06 2022-04-06 730
# ---->  2020-04-06 2026-04-06 2191
# ---->  24
#  24
#  2020-04-06 2021-07-06 456
# ---->  5
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 161469.483333333332496.887857142905  909912.86
# 968816.9
# 665296.485686.8658333333 831620.5
# Monthly 1028242.39
# 98087.17 2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 588523.02
#  2020-04-06 2022-04-06 730
# ---->  24
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# Monthly43329.183809523856 2020-04-06 2024-04-06 1461
# ---->  48
#  909912.86
# Quaterly 2020-04-06 2021-07-06 456
# ---->  5
# 201836.85416666663 968816.9
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 122608.9625John Nomination Number SCC604458 588523.02
# Monthly
#  2020-04-06 2022-04-06 730
# ---->  24
# 107108.58229166664 Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# 54161.479761904804242204.22499999998 909912.86
#  968816.9
# 1028242.39
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 147130.755Monthly 588523.02
#  2020-04-06 2022-04-06 Monthly730
# ---->  24
#  2020-04-06 2024-04-06 1461
# ---->  48
# Quaterly64993.77571428576 909912.86
#  2020-04-06 2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 128530.29874999997 1028242.39
# 282571.5958333333 968816.9
# 171652.54750000002 Monthly75826.07166666671 2020-04-06 2024-04-06 1461
# ---->  48
#  909912.86
# 588523.02Monthly
#  Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 2020-04-06Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
#  2022-04-06 730
# ---->  149952.015208333324 1028242.39
#
# 86658.36761904767 909912.86
# 196174.34000000003 588523.02
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 322938.9666666667MonthlyQuaterly 968816.9
#  2020-04-06 2026-04-06 2191
# ---->  24
#  2020-04-06 2027-04-06 2556
# ---->  84
# 171373.73166666663220696.13250000004 588523.02
#  1028242.39
# Monthly97490.66357142862 2020-04-06 2022-04-06 730
# ---->  24
#  909912.86
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# MonthlyMonthly 2020-04-06 2024-04-06 1461
# ---->  48
#  2020-04-06 2027-04-06 2556
# ---->  84
# 363306.3375 968816.9
# 245217.92500000005 588523.02
# 108322.95952380958 909912.86
# Monthly 192795.44812499997Quaterly 1028242.39
#  2020-04-06 2026-04-06 2191
# ---->  24
# Monthly2020-04-06 2020-04-06 2027-04-06 2556
# ---->  84
#  2022-04-06 730
# ---->  24
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 403673.7083333334269739.7175  588523.02
# 968816.9
# 119155.25547619053 909912.86
# MonthlyMonthly 2020-04-06 2022-04-06 730
# ---->  24
# 214217.1645833333 2020-04-06 2027-04-06 2556
# ---->  84
#  1028242.39
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 129987.55142857149444041.0791666667 968816.9
#  294261.51 588523.02
# 909912.86
# Quaterly235638.88104166664Monthly 1028242.39
#  2020-04-06 2022-04-06 730
# ---->  24
#  Monthly2020-04-06 2026-04-06 2191
# ---->  24
#  2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 484408.45000000007 968816.9
# 140819.84738095244 909912.86
# 318783.3025Monthly 588523.02
#  2020-04-06 2022-04-06 730
# ---->  24
# Monthly257060.59749999997 2020-04-06 2027-04-06 2556
# ---->  84
#  1028242.39
# QuaterlyMonthly 2020-04-06 2026-04-06 2191
# ---->  24
#  2020-04-06 2024-04-06 1461
# ---->  48
# 524775.8208333334 968816.9
# 151652.1433333334343305.095278482.3139583333 909912.86 1028242.39
#
#  588523.02
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 565143.1916666668Monthly  2020-04-06 2024-04-06 1461
# ---->  48
# 968816.9
# 367826.88749999995 588523.02
# 162484.43928571435Monthly 2020-04-06 2022-04-06 730
# ---->  24
#  909912.86
# 299904.0304166666 1028242.39
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 605510.5625000001 968816.9
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# 173316.7352380953392348.67999999993 588523.02
#  321325.7468749999909912.86 1028242.39
#
# 645877.9333333335Quaterly  2020-04-06 2026-04-06 2191
# ---->  24
# Monthly968816.9
#  2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# ----> 184149.03119047626  909912.86
# 416870.472499999948 588523.02
#
# MonthlyQuaterly 2020-04-06 2026-04-06 2191
# ---->  24
# 686245.3041666668  968816.9
# 2020-04-06342747.4633333332 1028242.39
#  2027-04-06Monthly  Monthly2556 2020-04-06 2024-04-06 1461
# ---->  48
#
# ---->  84
# 441392.26499999992020-04-06 2022-04-06 730
# ---->  24
#  588523.02
# Quaterly364169.1797916665 726612.6750000002194981.32714285722 968816.9
#  909912.86
#  2020-04-061028242.39
#  2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 465914.0574999999 588523.02
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 766980.0458333335 968816.9
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# 205813.62309523817385590.8962499998 909912.86
#  1028242.39
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# Monthly490435.84999999986 2020-04-06 2027-04-06 2556
# ---->  84
#  588523.02
# 807347.4166666669 968816.9
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# 407012.6127083331216645.91904761913 1028242.39
#  909912.86
# 847714.7875000002 968816.9
# Monthly514957.64249999984Monthly 588523.02
#  2020-04-06 2024-04-06 1461
# ---->  48
#  2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# Quaterly428434.32916666643  1028242.39
# 2020-04-06 2026-04-06 2191
# ---->  24
# 227478.21500000008 909912.86
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 888082.1583333336539479.4349999998  588523.02
# Monthly968816.9
#  2020-04-06 2027-04-06 2556
# ---->  84
# 449856.04562499974 1028242.39
# Quaterly 2020-04-06 2026-04-06 2191
# ---->  24
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 238310.51095238104 909912.86
# 564001.2274999998 588523.02
# Monthly928449.5291666669 471277.76208333304 968816.9
# 2020-04-06 2027-04-06 2556
# Quaterly---->  84
#  2020-04-06 2026-04-06 2191
# ---->  24
#  1028242.39
# Monthly 2020-04-06 2022-04-06 730
# ---->  24
# William Nomination Number SCC094589Monthly 2020-04-06 2024-04-06 1461
# ---->  48
#
# 249142.806904762 909912.86
# John Nomination Number SCC604458
# Monthly 492699.478541666352020-04-06 1028242.39
#  2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 259975.10285714295 909912.86
# 514121.19499999966Monthly 1028242.39 2020-04-06 2027-04-06 2556
# ---->  84
#
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 270807.3988095239 909912.86
# 535542.911458333Monthly 1028242.39
#  2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 281639.69476190483 909912.86
# 556964.6279166663 1028242.39
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 292471.99071428576 909912.86
# 578386.3443749996 1028242.39
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 303304.2866666667 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 599808.060833333 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 314136.5826190476 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 621229.7772916663 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 324968.87857142853 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 642651.4937499996 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 335801.17452380946 909912.86
# 664073.2102083329Monthly 1028242.39
#  2020-04-06 2027-04-06 2556
# ---->  84
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 346633.4704761904 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 685494.9266666662 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 357465.7664285713 909912.86
# 706916.6431249995 Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 368298.06238095224 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 728338.3595833328 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 379130.35833333316 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 749760.0760416661 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 389962.6542857141 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 771181.7924999994 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 400794.950238095 909912.86
# Monthly792603.5089583327 2020-04-06 2027-04-06 2556
# ---->  84
#  1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 411627.24619047594 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 814025.225416666 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 422459.54214285687 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 835446.9418749993 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 433291.8380952378 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 856868.6583333326 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 444124.1340476187 909912.86
# Monthly 2020-04-06 2027-04-06 2556878290.3747916659
#  ---->  84
# 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 454956.42999999964 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 899712.0912499992 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 465788.72595238057 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 921133.8077083325 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 476621.0219047615 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 942555.5241666659 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 487453.3178571424 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 963977.2406249992 1028242.39
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# 498285.61380952335 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 985398.9570833325 1028242.39
# 509117.9097619043 909912.86
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 1006820.6735416658 1028242.39
# 519950.2057142852 909912.86
# Monthly 2020-04-06 2024-04-06 1461
# ---->  48
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# Alexander Nomination Number SCC781571
# 530782.5016666661 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 541614.7976190471 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 552447.0935714281 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 563279.3895238091 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 574111.6854761901 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 584943.981428571 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 595776.277380952 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 606608.573333333 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 617440.869285714 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 628273.165238095 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 639105.461190476 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 649937.757142857 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 660770.0530952379 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 671602.3490476189 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 682434.6449999999 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 693266.9409523809 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 704099.2369047619 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 714931.5328571429 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 725763.8288095238 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 736596.1247619048 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 747428.4207142858 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 758260.7166666668 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 769093.0126190478 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 779925.3085714288 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 790757.6045238097 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 801589.9004761907 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 812422.1964285717 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 823254.4923809527 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 834086.7883333337 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 844919.0842857147 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 855751.3802380956 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 866583.6761904766 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 877415.9721428576 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 888248.2680952386 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# 899080.5640476196 909912.86
# Monthly 2020-04-06 2027-04-06 2556
# ---->  84
# Bethany Nomination Number SCC883620

# %% [markdown]
# # OTHER DATA POPULATE

# %%
def pop_cashColl(arg):
    start_date = parser.parse("2015-04-01")
    end_date = start_date
    print('started')
    
    print('new  -------------------------- ')
    args = chunks(models.employee_interview.objects.all() , 5)[arg]
    
    for i ,e in enumerate(args):
        print("employee" ,e.first_name)
        for day in range(400):
            end_date += relativedelta(days=+1)
#             print("end_date ", end_date)

            today_d = e.collection_deposit_set.filter(payment_received_date=end_date).values_list("payment_received")

            today_f = e.collection_finance_set.filter(loan_emi_received_date=end_date).values_list("loan_emi_received")

            day_total = sum([i[0] for i in today_d]) + sum([i[0] for i in today_f])

            if(day_total):
                k_ = {
                    "employee": e,
                    "total_society_deposit" : sum([i[0] for i in today_d]) ,
                    "total_loan_deposit" : sum([i[0] for i in today_f]),
                    "date" : end_date,
                    "remarks" : "-"
                }
                models.cash_collection(**k_).save()

                print(f"Thread:{arg} emp :{i} / {len(args)}  \ncreated on " ,end_date)

        end_date = start_date
        print("resetting" , end_date)

for arg in range(2):
    Thread(target=pop_cashColl ,args=(arg , )).start()
# Out:
# started
# new  --------------------------
# started
# new  --------------------------
# employeeemployee Walter
#  Sheila
# Thread:1 emp :0 / 5
# created on  2015-08-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-08-28 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-09-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-09-24 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-10-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-10-21 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-11-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-11-08 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-11-15 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-11-17 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-11-22 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-11-29 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-12-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-12-06 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-12-13 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-12-14 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-12-20 00:00:00
# Thread:1 emp :0 / 5
# created on  2015-12-27 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-01-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-01-03 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-01-10 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-01-17 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-01-24 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-01-31 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-02-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-02-06 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-02-07 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-02-14 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-02-21 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-02-28 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-03-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-03-04 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-03-06 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-03-13 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-03-20 00:00:00
# resetting 2015-04-01 00:00:00
# employee Juan
# Thread:1 emp :0 / 5
# created on  2016-03-27 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-03-31 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-04-01 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-04-03 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-04-10 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-04-17 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-04-24 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-04-27 00:00:00
# Thread:1 emp :0 / 5
# created on  2016-05-01 00:00:00
# resetting 2015-04-01 00:00:00
# employee Amy
# Thread:1 emp :1 / 5
# created on  2015-10-01 00:00:00
# Thread:1 emp :1 / 5
# created on  2015-11-01 00:00:00
# Thread:1 emp :1 / 5
# created on  2015-12-01 00:00:00
# Thread:1 emp :1 / 5
# created on  2016-01-01 00:00:00
# Thread:1 emp :1 / 5
# created on  2016-02-01 00:00:00
# Thread:1 emp :1 / 5
# created on  2016-03-01 00:00:00
# resetting 2015-04-01 00:00:00
# employee Jason
# Thread:1 emp :1 / 5
# created on  2016-04-01 00:00:00
# Thread:1 emp :1 / 5
# created on  2016-05-01 00:00:00
# resetting 2015-04-01 00:00:00
# employee Karl
# Thread:0 emp :2 / 5
# created on  2016-01-01 00:00:00
# resetting 2015-04-01 00:00:00
# employee John
# resetting 2015-04-01 00:00:00
# employee Tonya
# Thread:0 emp :3 / 5
# created on  2015-09-20 00:00:00
# Thread:1 emp :3 / 5
# created on  2015-08-01 00:00:00
# Thread:0 emp :3 / 5
# created on  2015-10-09 00:00:00
# Thread:0 emp :3 / 5
# created on  2015-10-28 00:00:00
# Thread:0 emp :3 / 5
# created on  2015-11-16 00:00:00
# Thread:0 emp :3 / 5
# created on  2015-12-05 00:00:00
# Thread:0 emp :3 / 5
# created on  2015-12-24 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-01-12 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-01-31 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-02-19 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-03-09 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-03-28 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-04-16 00:00:00
# Thread:0 emp :3 / 5
# created on  2016-05-05 00:00:00
# resetting 2015-04-01 00:00:00
# employee Sharon
# resetting 2015-04-01 00:00:00
# employee Jason
# Thread:1 emp :4 / 5
# created on  2015-05-30 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-06-28 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-07-27 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-08-01 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-08-25 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-09-23 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-10-22 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-11-01 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-11-20 00:00:00
# Thread:1 emp :4 / 5
# created on  2015-12-19 00:00:00
# Thread:1 emp :4 / 5
# created on  2016-01-17 00:00:00
# Thread:1 emp :4 / 5
# created on  2016-02-15 00:00:00
# resetting 2015-04-01 00:00:00
# Thread:1 emp :4 / 5
# created on  2016-03-15 00:00:00
# Thread:1 emp :4 / 5
# created on  2016-04-13 00:00:00
# resetting 2015-04-01 00:00:00

# %%
def dp_withdrawl():
    
    for dp in models.deposits_table.objects.all():
        
        if('FD' in dp.scheme.name):
            cat = "Maturity"
            w_date = dp.maturity_date 
            interest = dp.maturity_amount
            w_amount = dp.maturity_amount
            
        else:
            cat = "withdraw"
            w_date = dp.account_opening_date + relativedelta(months=+1)
            interest = dp.scheme.per_day_roi * (w_date - dp.account_opening_date).days * dp.account_opening_amount
            w_amount = np.random.randint(200,2000)
            
        k_ ={
            "society_account" : dp,
            "holder_name" : dp.person.first_name,
            "category" : cat,
            "amount_withdrawl_date" : w_date,
            "available_amount" : dp.balance,
            "intrest_amount" : interest,
            "amount_withdrawl" : w_amount
        }
        
        models.withdrawl_entry(**k_).save()
        print(dp)
        
Thread(target=dp_withdrawl).start()
# Out:
# 19200406337FD
# 19200406833FD
# 19200406155FD
# 19200406271FD
# 19200406475RD
# 19200406291CA
# 19200406430RD
# 19200406132CA
# 19200406879CA
# 19200406277CA

# %%
def cashColl_Vouchers():
    models.Voucher.objects.all().delete()
    
    for coll in models.cash_collection.objects.all().order_by('date'):
        
        #collection vouchers
        
        k_ = {
            'date' : coll.date,
            'transact_type' : 'Cr',
            'voucher_type' : "Journal" ,
            'head' : "Employee Collection : " + coll.employee.first_name,
            "title" : "Credit from " +coll.employee.first_name,
            'amount' : coll.total_society_deposit + coll.total_loan_deposit
        }
        
        v_ = models.Voucher.objects.create(**k_)
        models.VoucherHead.objects.create(head= "Employee Collection : " + coll.employee.first_name ,voucher = v_)
        
        
        ##Daily Expenses Vouchers
        k_ = {
            'date' : coll.date,
            'transact_type' : 'Dr',
            'voucher_type' : "Payment" ,
            'head' : "Employee Expense : " + coll.employee.first_name,
            "title" : "Credit To " +coll.employee.first_name,
            'amount' : np.random.randint(50,1000)
        }
        
        v_ = models.Voucher.objects.create(**k_)
        models.VoucherHead.objects.create(head= "Employee Expense : " + coll.employee.first_name ,voucher = v_)
        
        
        print(coll)
            
Thread(target=cashColl_Vouchers).start()
# Out:
# 0.0  ---- holy cash
# 500.0  ---- holy cash
# cash_collection object (1759)
# 230.0  ---- holy cash
# 1830.0  ---- holy cash
# cash_collection object (1760)
# 1375.0  ---- holy cash
# 3275.0  ---- holy cash
# cash_collection object (1761)
# 2697.0  ---- holy cash
# 1030939.39  ---- holy cash
# cash_collection object (1746)
# 1030140.39  ---- holy cash
# 1030740.39  ---- holy cash
# cash_collection object (1692)
# 1030159.39  ---- holy cash
# 1940072.25  ---- holy cash
# cash_collection object (1762)
# 1939714.25  ---- holy cash
# 1941014.25  ---- holy cash
# cash_collection object (1763)
# 1940544.25  ---- holy cash
# 1941044.25  ---- holy cash
# cash_collection object (1693)
# 1940378.25  ---- holy cash
# 1942078.25  ---- holy cash
# cash_collection object (1694)
# 1941565.25  ---- holy cash
# 1942165.25  ---- holy cash
# cash_collection object (1745)
# 1941202.25  ---- holy cash
# 1942202.25  ---- holy cash
# cash_collection object (1764)
# 1942052.25  ---- holy cash
# 1942752.25  ---- holy cash
# cash_collection object (1695)
# 1942501.25  ---- holy cash
# 1944101.25  ---- holy cash
# cash_collection object (1696)
# 1943366.25  ---- holy cash
# 1944966.25  ---- holy cash
# cash_collection object (1736)
# 1944262.25  ---- holy cash
# 1944962.25  ---- holy cash
# cash_collection object (1747)
# 1944286.25  ---- holy cash
# 1945886.25  ---- holy cash
# cash_collection object (1697)
# 1945626.25  ---- holy cash
# 1946526.25  ---- holy cash
# cash_collection object (1765)
# 1946315.25  ---- holy cash
# 1947015.25  ---- holy cash
# cash_collection object (1748)
# 1946236.25  ---- holy cash
# 2778356.75  ---- holy cash
# cash_collection object (1737)
# 2777815.75  ---- holy cash
# 2778615.75  ---- holy cash
# cash_collection object (1698)
# 2777683.75  ---- holy cash
# 3403917.59  ---- holy cash
# cash_collection object (1766)
# 3402943.59  ---- holy cash
# 3404043.59  ---- holy cash
# cash_collection object (1699)
# 3403453.59  ---- holy cash
# 3404153.59  ---- holy cash
# cash_collection object (1700)
# 3403990.59  ---- holy cash
# 3405190.59  ---- holy cash
# cash_collection object (1749)
# 3405111.59  ---- holy cash
# 3406911.59  ---- holy cash
# cash_collection object (1701)
# 3405981.59  ---- holy cash
# 3406681.59  ---- holy cash
# cash_collection object (1767)
# 3406172.59  ---- holy cash
# 3407872.59  ---- holy cash
# cash_collection object (1702)
# 3407048.59  ---- holy cash
# 3407848.59  ---- holy cash
# cash_collection object (1703)
# 3407736.59  ---- holy cash
# 3408636.59  ---- holy cash
# cash_collection object (1738)
# 3408141.59  ---- holy cash
# 3410041.59  ---- holy cash
# cash_collection object (1704)
# 3409116.59  ---- holy cash
# 3409916.59  ---- holy cash
# cash_collection object (1750)
# 3408996.59  ---- holy cash
# 3409996.59  ---- holy cash
# cash_collection object (1705)
# 3409174.59  ---- holy cash
# 3410574.59  ---- holy cash
# cash_collection object (1706)
# 3409997.59  ---- holy cash
# 3410997.59  ---- holy cash
# cash_collection object (1707)
# 3410404.59  ---- holy cash
# 3411504.59  ---- holy cash
# cash_collection object (1768)
# 3410565.59  ---- holy cash
# 3411065.59  ---- holy cash
# cash_collection object (1708)
# 3410450.59  ---- holy cash
# 3412050.59  ---- holy cash
# cash_collection object (1751)
# 3411350.59  ---- holy cash
# 3412150.59  ---- holy cash
# cash_collection object (1709)
# 3411340.59  ---- holy cash
# 3412740.59  ---- holy cash
# cash_collection object (1710)
# 3412423.59  ---- holy cash
# 4381840.49  ---- holy cash
# cash_collection object (1739)
# 4381246.49  ---- holy cash
# 4969769.51  ---- holy cash
# cash_collection object (1744)
# 4969322.51  ---- holy cash
# 4970422.51  ---- holy cash
# cash_collection object (1711)
# 4969827.51  ---- holy cash
# 4973327.51  ---- holy cash
# cash_collection object (1712)
# 4972555.51  ---- holy cash
# 4974355.51  ---- holy cash
# cash_collection object (1752)
# 4974161.51  ---- holy cash
# 4974761.51  ---- holy cash
# cash_collection object (1713)
# 4973898.51  ---- holy cash
# 4975198.51  ---- holy cash
# cash_collection object (1769)
# 4975121.51  ---- holy cash
# 4975821.51  ---- holy cash
# cash_collection object (1714)
# 4975085.51  ---- holy cash
# 4976185.51  ---- holy cash
# cash_collection object (1753)
# 4975358.51  ---- holy cash
# 4976258.51  ---- holy cash
# cash_collection object (1715)
# 4975519.51  ---- holy cash
# 4976919.51  ---- holy cash
# cash_collection object (1740)
# 4976059.51  ---- holy cash
# 4977659.51  ---- holy cash
# cash_collection object (1716)
# 4976676.51  ---- holy cash
# 4977376.51  ---- holy cash
# cash_collection object (1717)
# 4977208.51  ---- holy cash
# 4977708.51  ---- holy cash
# cash_collection object (1718)
# 4976740.51  ---- holy cash
# 4978240.51  ---- holy cash
# cash_collection object (1719)
# 4977261.51  ---- holy cash
# 4978961.51  ---- holy cash
# cash_collection object (1770)
# 4978642.51  ---- holy cash
# 4979442.51  ---- holy cash
# cash_collection object (1754)
# 4978622.51  ---- holy cash
# 4979122.51  ---- holy cash
# cash_collection object (1720)
# 4978783.51  ---- holy cash
# 4979983.51  ---- holy cash
# cash_collection object (1721)
# 4979525.51  ---- holy cash
# 4980025.51  ---- holy cash
# cash_collection object (1722)
# 4979619.51  ---- holy cash
# 4980619.51  ---- holy cash
# cash_collection object (1741)
# 4980491.51  ---- holy cash
# 4981391.51  ---- holy cash
# cash_collection object (1723)
# 4980525.51  ---- holy cash
# 4981825.51  ---- holy cash
# cash_collection object (1724)
# 4981416.51  ---- holy cash
# 4982616.51  ---- holy cash
# cash_collection object (1755)
# 4981700.51  ---- holy cash
# 4983300.51  ---- holy cash
# cash_collection object (1725)
# 4983231.51  ---- holy cash
# 4983831.51  ---- holy cash
# cash_collection object (1771)
# 4983148.51  ---- holy cash
# 4983848.51  ---- holy cash
# cash_collection object (1726)
# 4983130.51  ---- holy cash
# 4984030.51  ---- holy cash
# cash_collection object (1727)
# 4983233.51  ---- holy cash
# 4984533.51  ---- holy cash
# cash_collection object (1756)
# 4983558.51  ---- holy cash
# 4985358.51  ---- holy cash
# cash_collection object (1728)
# 4984996.51  ---- holy cash
# 4985696.51  ---- holy cash
# cash_collection object (1742)
# 4985136.51  ---- holy cash
# 4986336.51  ---- holy cash
# cash_collection object (1729)
# 4986021.51  ---- holy cash
# 4986921.51  ---- holy cash
# cash_collection object (1730)
# 4986139.51  ---- holy cash
# 4987339.51  ---- holy cash
# cash_collection object (1731)
# 4987275.51  ---- holy cash
# 4989075.51  ---- holy cash
# cash_collection object (1772)
# 4988625.51  ---- holy cash
# 4989125.51  ---- holy cash
# cash_collection object (1757)
# 4988656.51  ---- holy cash
# 4989156.51  ---- holy cash
# cash_collection object (1732)
# 4989061.51  ---- holy cash
# 4989961.51  ---- holy cash
# cash_collection object (1733)
# 4989878.51  ---- holy cash
# 4991778.51  ---- holy cash
# cash_collection object (1734)
# 4991446.51  ---- holy cash
# 4992846.51  ---- holy cash
# cash_collection object (1743)
# 4992779.51  ---- holy cash
# 4994579.51  ---- holy cash
# cash_collection object (1735)
# 4994343.51  ---- holy cash
# 4995543.51  ---- holy cash
# cash_collection object (1758)

# %% [markdown]
# # Dump DATA

# %%
p = Populate()

# %%
p.start()

# %%
import re
from PIL import Image
import requests
from io import BytesIO
from PIL import Image, ImageOps, ImageDraw


s = 'Today <ent src="https://robohub.org/wp-content/uploads/2017/02/grid-AI.jpg">artificial Intelligence</ent> (AI) is the sexiest topic of industry with endless possibilities and has been a part of our daily lives from a long time. You are using it while binge watching <ent src="https://www.wired.com/wp-content/uploads/2015/05/Netflix_Logo_Digital-Video.jpg">Netflix</ent> or Youtube , asking Siri to take notes, as well as searching for cats on google'

# %%
import requests as req
from bs4 import BeautifulSoup

q = "person"

for i in range(0,100,2):

    page = req.get(f'https://www.google.com/search?q={q}&tbm=isch&start={i}')
    soup  =  BeautifulSoup(page.text, 'html.parser')
    #parse all 10 images and return the first one 
    imgs = [i['src'] for i in soup.find_all("img") if(i.has_key('src') and 'gstatic.com' in i['src']) ]
    for j ,img in enumerate(imgs):
        response = req.get(img)
        img = Image.open(BytesIO(response.content))
        img = img.convert('RGB')
        img.save(f'/Users/vaqasahmed/Desktop/Desktop – vaqas’s MacBook Pro/django-text/banking_dump/employee/static/employee/person/{i+j}.png')
        print('saved  --- ',i+j)

# %%
import base64

with open("static/employee/NOC.ejpeg", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read())

# %%
open('t.html' ,'w').write(page.text)
